# %%
import numpy as np
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYzQ1YjQ4YjE2NmVlODVjMjA3ZWEyNTc4ZGYxNGU3YyIsInN1YiI6IjY2NjA3ZTE3ZDc2Y2UwNGU2ZGI3NDdkNiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2v9C0a8ctAkBseEsYxXec4lGdbJY004iikzoe5LxUWY"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true,"status_code":1,"status_message":"Success."}

# %%
import requests
import pandas as pd
import time

# URL base y headers para la solicitud
base_url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page="
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYzQ1YjQ4YjE2NmVlODVjMjA3ZWEyNTc4ZGYxNGU3YyIsInN1YiI6IjY2NjA3ZTE3ZDc2Y2UwNGU2ZGI3NDdkNiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2v9C0a8ctAkBseEsYxXec4lGdbJY004iikzoe5LxUWY"
}

all_movies = []

# El siguiente bucle realizará 472 solicitudes, una por cada página que componen el listado de Top Rated Movies

for page in range(1, 473):
    url = f"{base_url}{page}"
    response = requests.get(url, headers=headers)

    # Verifica si la solicitud fue exitosa

    if response.status_code == 200:
        data = response.json()  # Convierte la respuesta a JSON
        movies = data['results']  # Extrae la lista de películas
        all_movies.extend(movies)  # Añade las películas a la lista completa
    else:
        print(f"Error en la solicitud de la página {page}: {response.status_code}")

    # Pausa para evitar ser bloqueado por la API
    time.sleep(0.5)

# Convierte la lista completa de películas en un dataframe de pandas
df = pd.DataFrame(all_movies)

# Guardar el dataframe a un archivo CSV
df.to_csv("top_rated_movies.csv", index=False)
# Out:
#       adult                     backdrop_path              genre_ids     id  \
# 0     False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg               [18, 80]    278
# 1     False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg               [18, 80]    238
# 2     False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg               [18, 80]    240
# 3     False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg        [18, 36, 10752]    424
# 4     False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                   [18]    389
# ...     ...                               ...                    ...    ...
# 9420  False  /lcLyZzhB1ctfdH0hGBsTFrbflqP.jpg           [28, 14, 27]  12142
# 9421  False  /5V6jAFS0Q49SI07qjyFRMYlbfR9.jpg              [35, 878]  13805
# 9422  False  /aNUEHLNsNMprLZt6fjf5nqDq6er.jpg           [27, 28, 53]  11059
# 9423  False  /oHrrgAPEKpz0S1ofQntiZNrmGrM.jpg  [28, 12, 14, 878, 53]  14164
# 9424  False  /wDrs28ZYYnXVIeb87H0dCYlWiFA.jpg        [10749, 27, 53]  40016
#
#      original_language              original_title  \
# 0                   en    The Shawshank Redemption
# 1                   en               The Godfather
# 2                   en       The Godfather Part II
# 3                   en            Schindler's List
# 4                   en                12 Angry Men
# ...                ...                         ...
# 9420                en           Alone in the Dark
# 9421                en              Disaster Movie
# 9422                en           House of the Dead
# 9423                en        Dragonball Evolution
# 9424                en  Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     Imprisoned in the 1940s for the double murder ...     130.490
# 1     Spanning the years 1945 to 1955, a chronicle o...     134.390
# 2     In the continuing saga of the Corleone crime f...     116.195
# 3     The true story of how businessman Oskar Schind...      79.028
# 4     The defense and the prosecution have rested an...      67.473
# ...                                                 ...         ...
# 9420  Edward Carnby is a private investigator specia...      18.238
# 9421  The filmmaking team behind the hits "Scary Mov...      28.616
# 9422  Set on an island off the coast, a techno rave ...      15.855
# 9423  On his 18th birthday, Goku receives a mystical...      28.599
# 9424  A platoon of eagles and vultures attacks the r...      12.653
#
#                            poster_path release_date  \
# 0     /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1     /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2     /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 3     /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 4     /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# ...                                ...          ...
# 9420  /bSxrbVCyWW077zhtpuYlo3zgyug.jpg   2005-01-28
# 9421  /3J8XKUfhJiNzwobUZVtizXYPe8b.jpg   2008-08-29
# 9422  /z2mDGbV4pLtsvSMNnmnSgoVZSWK.jpg   2003-04-11
# 9423   /sunS9xhPnFNP5wlOWrvbpBteAB.jpg   2009-03-12
# 9424  /gqmcAVNNUosB55RliecFYnkWT4M.jpg   2010-02-27
#
#                            title  video  vote_average  vote_count
# 0       The Shawshank Redemption  False         8.706       26271
# 1                  The Godfather  False         8.695       19922
# 2          The Godfather Part II  False         8.577       12029
# 3               Schindler's List  False         8.568       15437
# 4                   12 Angry Men  False         8.542        8298
# ...                          ...    ...           ...         ...
# 9420           Alone in the Dark  False         3.244         583
# 9421              Disaster Movie  False         3.187         999
# 9422           House of the Dead  False         3.142         372
# 9423        Dragonball Evolution  False         2.897        1988
# 9424  Birdemic: Shock and Terror  False         2.199         322
#
# [9425 rows x 14 columns]

# %%
top_rated_movies_raw = df

# %%
top_rated_movies_raw.head(10)
# Out:
#    adult                     backdrop_path         genre_ids      id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 5  False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]   19404
# 6  False  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg   [16, 10751, 14]     129
# 7  False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]     155
# 8  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg      [35, 53, 18]  496243
# 9  False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]     497
#
#   original_language                original_title  \
# 0                en      The Shawshank Redemption
# 1                en                 The Godfather
# 2                en         The Godfather Part II
# 3                en              Schindler's List
# 4                en                  12 Angry Men
# 5                hi  दिलवाले दुल्हनिया ले जायेंगे
# 6                ja                      千と千尋の神隠し
# 7                en               The Dark Knight
# 8                ko                           기생충
# 9                en                The Green Mile
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     130.490
# 1  Spanning the years 1945 to 1955, a chronicle o...     134.390
# 2  In the continuing saga of the Corleone crime f...     116.195
# 3  The true story of how businessman Oskar Schind...      79.028
# 4  The defense and the prosecution have rested an...      67.473
# 5  Raj is a rich, carefree, happy-go-lucky second...      45.694
# 6  A young girl, Chihiro, becomes trapped in a st...     117.948
# 7  Batman raises the stakes in his war on crime. ...      99.684
# 8  All unemployed, Ki-taek's family takes peculia...     123.914
# 9  A supernatural tale set on death row in a Sout...     100.392
#
#                         poster_path release_date                        title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23     The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14                The Godfather
# 2  /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20        The Godfather Part II
# 3  /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15             Schindler's List
# 4  /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10                 12 Angry Men
# 5  /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20  Dilwale Dulhania Le Jayenge
# 6  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20                Spirited Away
# 7  /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16              The Dark Knight
# 8  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30                     Parasite
# 9  /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10               The Green Mile
#
#    video  vote_average  vote_count
# 0  False         8.706       26271
# 1  False         8.695       19922
# 2  False         8.577       12029
# 3  False         8.568       15437
# 4  False         8.542        8298
# 5  False         8.537        4395
# 6  False         8.537       15991
# 7  False         8.516       32039
# 8  False         8.510       17615
# 9  False         8.505       16880

# %%
top_rated_movies_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              9425 non-null   bool
#  1   backdrop_path      9418 non-null   object
#  2   genre_ids          9425 non-null   object
#  3   id                 9425 non-null   int64
#  4   original_language  9425 non-null   object
#  5   original_title     9425 non-null   object
#  6   overview           9425 non-null   object
#  7   popularity         9425 non-null   float64
#  8   poster_path        9422 non-null   object
#  9   release_date       9425 non-null   object
#  10  title              9425 non-null   object
#  11  video              9425 non-null   bool
#  12  vote_average       9425 non-null   float64
#  13  vote_count         9425 non-null   int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 902.1+ KB

# %%
# Creamos una copia del dataframe para quedarnos con las primmeras 1000 películas 

top_1000_rated_movies = top_rated_movies_raw.head(1000)

# Guardamos los elementos que componen la columna "id" del dataframe en una lista 

id_list = top_1000_rated_movies['id'].tolist()

# len(id_list)

# %%
# URL base y headers para la solicitud
base_url = "https://api.themoviedb.org/3/movie/"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYzQ1YjQ4YjE2NmVlODVjMjA3ZWEyNTc4ZGYxNGU3YyIsInN1YiI6IjY2NjA3ZTE3ZDc2Y2UwNGU2ZGI3NDdkNiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2v9C0a8ctAkBseEsYxXec4lGdbJY004iikzoe5LxUWY"
}

data_all_movies = []

# Realiza una solicitud para cada identificador de película en la lista
for movie_id in id_list:
    url = f"{base_url}{movie_id}?language=en-US"
    response = requests.get(url, headers=headers)

    # Verifica si la solicitud fue exitosa
    if response.status_code == 200:
        movie_data = response.json()  # Convierte la respuesta a JSON
        data_all_movies.append(movie_data)  # Añade los datos de la película a la lista
    else:
        print(f"Error en la solicitud para la película ID {movie_id}: {response.status_code}")

    # Pausa para evitar ser bloqueado por la API
    time.sleep(0.5)

# Convierte la lista completa de películas en un dataframe de pandas
data_top_1000_movies = pd.DataFrame(data_all_movies)


# Guardar el dataframe a un archivo CSV (opcional)
data_top_1000_movies.to_csv("data_all_movies.csv", index=False)

# %%
top_1000_rated_movies.iloc[0]
# Out:
# adult                                                            False
# backdrop_path                         /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg
# genre_ids                                                     [18, 80]
# id                                                                 278
# original_language                                                   en
# original_title                                The Shawshank Redemption
# overview             Imprisoned in the 1940s for the double murder ...
# popularity                                                      130.49
# poster_path                           /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg
# release_date                                                1994-09-23
# title                                         The Shawshank Redemption
# video                                                            False
# vote_average                                                     8.706
# vote_count                                                       26271
# Name: 0, dtype: object

# %%
data_top_1000_movies.iloc[0]
# Out:
# adult                                                                False
# backdrop_path                             /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg
# belongs_to_collection                                                 None
# budget                                                            25000000
# genres                   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# homepage
# id                                                                     278
# imdb_id                                                          tt0111161
# origin_country                                                        [US]
# original_language                                                       en
# original_title                                    The Shawshank Redemption
# overview                 Imprisoned in the 1940s for the double murder ...
# popularity                                                          130.49
# poster_path                               /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg
# production_companies     [{'id': 97, 'logo_path': '/7znWcbDd4PcJzJUlJxY...
# production_countries     [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    1994-09-23
# revenue                                                           28341469
# runtime                                                                142
# spoken_languages         [{'english_name': 'English', 'iso_639_1': 'en'...
# status                                                            Released
# tagline                  Fear can hold you prisoner. Hope can set you f...
# title                                             The Shawshank Redemption
# video                                                                False
# vote_average                                                         8.705
# vote_count                                                           26271
# Name: 0, dtype: object

# %%
data_top_1000_movies.iloc[999]['genres']
# Out:
# [{'id': 878, 'name': 'Science Fiction'}, {'id': 18, 'name': 'Drama'}]
